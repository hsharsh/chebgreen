# %%
from chebGreen import ChebGreen
import numpy as np
import matplotlib.pyplot as plt

from chebGreen.chebpy2 import Quasimatrix
from chebGreen.chebpy2.chebpy import chebfun
from chebGreen.chebpy2 import Chebfun2

# %env TF_MLC_LOGGING=1
# %env TF_CPP_MIN_LOG_LEVEL=2

# %%
Theta = [5e-2, 6e-2, 8e-2]
domain = [0,1,0,1]
generateData = True
script = "generate_example"
example = "interior_layer"
dirichletBC = True
schrodinger = ChebGreen(Theta, domain, generateData, script, example, dirichletBC)
# Out:
# Generating dataset for example 'interior_layer'
# ### Example = interior_layer @ theta = 0.05 ###
# Number of samples: 100
# Length scale: 0.01
# Nf: 500
# Nu: 500
# Noise: 0%
# ---------------------------------------
# Step = 1/100
# Step = 2/100
# Step = 3/100
# Step = 4/100
# Step = 5/100
# Step = 6/100
# Step = 7/100
# Step = 8/100
# Step = 9/100
# Step = 10/100
# Step = 11/100
# Step = 12/100
# Step = 13/100
# Step = 14/100
# Step = 15/100
# Step = 16/100
# Step = 17/100
# Step = 18/100
# Step = 19/100
# Step = 20/100
# Step = 21/100
# Step = 22/100
# Step = 23/100
# Step = 24/100
# Step = 25/100
# Step = 26/100
# Step = 27/100
# Step = 28/100
# Step = 29/100
# Step = 30/100
# Step = 31/100
# Step = 32/100
# Step = 33/100
# Step = 34/100
# Step = 35/100
# Step = 36/100
# Step = 37/100
# Step = 38/100
# Step = 39/100
# Step = 40/100
# Step = 41/100
# Step = 42/100
# Step = 43/100
# Step = 44/100
# Step = 45/100
# Step = 46/100
# Step = 47/100
# Step = 48/100
# Step = 49/100
# Step = 50/100
# Step = 51/100
# Step = 52/100
# Step = 53/100
# Step = 54/100
# Step = 55/100
# Step = 56/100
# Step = 57/100
# Step = 58/100
# Step = 59/100
# Step = 60/100
# Step = 61/100Dataset found for Theta = 0.06. Skipping dataset generation.
# Dataset found for Theta = 0.08. Skipping dataset generation.
# -------------------------------------------------------------------------------
#
# Generating chebfun2 models:
#
# Step = 62/100
# Step = 63/100
# Step = 64/100
# Step = 65/100
# Step = 66/100
# Step = 67/100
# Step = 68/100
# Step = 69/100
# Step = 70/100
# Step = 71/100
# Step = 72/100
# Step = 73/100
# Step = 74/100
# Step = 75/100
# Step = 76/100
# Step = 77/100
# Step = 78/100
# Step = 79/100
# Step = 80/100
# Step = 81/100
# Step = 82/100
# Step = 83/100
# Step = 84/100
# Step = 85/100
# Step = 86/100
# Step = 87/100
# Step = 88/100
# Step = 89/100
# Step = 90/100
# Step = 91/100
# Step = 92/100
# Step = 93/100
# Step = 94/100
# Step = 95/100
# Step = 96/100
# Step = 97/100
# Step = 98/100
# Step = 99/100
# Step = 100/100
# Training greenlearning model for example 'interior_layer' at Theta = 0.05
# Training with Adam:
# Loss at epoch 100: Training = 4.780E-01, Validation = 5.326E-01
# Loss at epoch 200: Training = 7.112E-02, Validation = 6.931E-02
# Loss at epoch 2400: Training = 2.955E-04, Validation = 5.926E-04
# Loss at epoch 2500: Training = 2.788E-04, Validation = 5.458E-04
# Loss at epoch 2600: Training = 2.789E-04, Validation = 5.122E-04
# Loss at epoch 2700: Training = 2.526E-04, Validation = 4.739E-04
# Loss at epoch 2800: Training = 2.401E-04, Validation = 4.406E-04
# Loss at epoch 2900: Training = 2.317E-04, Validation = 4.133E-04
# Loss at epoch 3000: Training = 2.201E-04, Validation = 3.897E-04
# Loss at epoch 3100: Training = 2.111E-04, Validation = 3.676E-04
# Loss at epoch 3200: Training = 2.023E-04, Validation = 3.469E-04
# Loss at epoch 3300: Training = 1.961E-04, Validation = 3.294E-04
# Loss at epoch 3400: Training = 1.880E-04, Validation = 3.143E-04
# Loss at epoch 3500: Training = 4.652E-04, Validation = 6.529E-04
# Loss at epoch 3600: Training = 1.751E-04, Validation = 2.866E-04
# Loss at epoch 3700: Training = 1.685E-04, Validation = 2.726E-04
# Loss at epoch 3800: Training = 1.877E-04, Validation = 2.670E-04
# Loss at epoch 3900: Training = 1.581E-04, Validation = 2.521E-04
# Loss at epoch 4000: Training = 1.524E-04, Validation = 2.408E-04
# Loss at epoch 4100: Training = 1.475E-04, Validation = 2.313E-04
# Loss at epoch 4200: Training = 1.426E-04, Validation = 2.224E-04
# Loss at epoch 4300: Training = 1.390E-04, Validation = 2.153E-04
# Loss at epoch 4400: Training = 1.344E-04, Validation = 2.074E-04
# Loss at epoch 4500: Training = 1.465E-04, Validation = 2.130E-04
# Loss at epoch 4600: Training = 1.269E-04, Validation = 1.946E-04
# Loss at epoch 4700: Training = 4.794E-04, Validation = 6.229E-04
# Loss at epoch 4800: Training = 1.200E-04, Validation = 1.840E-04
# Loss at epoch 4900: Training = 1.164E-04, Validation = 1.780E-04
# Loss at epoch 5000: Training = 1.139E-04, Validation = 1.757E-04
# Training with LBFGS:
# Learning a chebfun model for example 'interior_layer' at Theta = 0.08
# Chebfun model added for example 'interior_layer' at Theta = 0.08

# %%
# %%time
for t in Theta:
    fig = plt.figure()
    schrodinger.G[t].plot(fig = fig)
    # error = schrodinger.computeEmpiricalError(t)
    error = 0
    plt.title(f"$\\theta = {{{t:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# Out:
# CPU times: user 8.32 s, sys: 11.2 s, total: 19.5 s
# Wall time: 6.59 s

# %%
# %%time
u,s,v = schrodinger.G[6e-2].svd()
# Out:
# CPU times: user 2.68 s, sys: 7.36 s, total: 10 s
# Wall time: 1.42 s

# %%
fig = plt.figure(figsize = (8,6))
plt.semilogy(s)

# %%
# i = slice(10,20)
i = slice(0,5)
# i = 16
fig = plt.figure(figsize = (8,6))
u[:,i].plot(fig = fig)
# print(np.max(u[:,i].vscale))
# plt.title(f'First {i+1} left singular functions for a Laplacian')
plt.xlim([0,1])
# fig.savefig(f'Laplace-first.png', dpi = fig.dpi)
# Out:
# (0.0, 1.0)

# %%
# %%time
theta_ = 7e-2
Ginterp, Ninterp = schrodinger.generateNewModel(theta_)
# Out:
# CPU times: user 19.6 s, sys: 42.5 s, total: 1min 2s
# Wall time: 11.9 s

# %%
Ginterp
# Out:
# chebfun2 object
#      domain       rank               corner values
# [0.0,1.0] x [0.0,1.0]     76       [-0.000 -0.000 -0.000 0.000]
# vertical scale = 1.956169

# %%
# %%time
u,s,v = Ginterp.svd()
# Out:
# CPU times: user 3.74 s, sys: 8.09 s, total: 11.8 s
# Wall time: 2.54 s

# %%
fig = plt.figure(figsize = (8,6))
plt.semilogy(s)

# %%
validation = ChebGreen([theta_], domain, generateData, script, example, dirichletBC)
# Out:
# Generating dataset for example 'interior_layer'
# ### Example = interior_layer @ theta = 0.07 ###
# Number of samples: 100
# Length scale: 0.01
# Nf: 500
# Nu: 500
# Noise: 0%
# ---------------------------------------
# Step = 1/100
# Step = 2/100
# Step = 3/100
# Step = 4/100
# Step = 5/100
# Step = 6/100
# Step = 7/100
# Step = 8/100
# Step = 9/100
# Step = 10/100
# Step = 11/100
# Step = 12/100
# Step = 13/100
# Step = 14/100
# Step = 15/100
# Step = 16/100
# Step = 17/100
# Step = 18/100
# Step = 19/100
# Step = 20/100
# Step = 21/100
# Step = 22/100
# Step = 23/100
# Step = 24/100
# Step = 25/100
# Step = 26/100
# Step = 27/100
# Step = 28/100
# Step = 29/100
# Step = 30/100
# Step = 31/100
# Step = 32/100
# Step = 33/100
# Step = 34/100
# Step = 35/100
# Step = 36/100
# Step = 37/100
# Step = 38/100
# Step = 39/100
# Step = 40/100
# Step = 41/100
# Step = 42/100
# Step = 43/100
# Step = 44/100
# Step = 45/100
# Step = 46/100
# Step = 47/100
# Step = 48/100
# Step = 49/100
# Step = 50/100
# Step = 51/100
# Step = 52/100
# Step = 53/100
# Step = 54/100
# Step = 55/100
# Step = 56/100
# Step = 57/100
# Step = 58/100
# Step = 59/100
# Step = 60/100
# Step = 61/100
# Step = 62/100
# Step = 63/100
# Step = 64/100
# Step = 65/100
# Step = 66/100
# Step = 67/100
# Step = 68/100
# Step = 69/100
# Step = 70/100
# Step = 71/100
# Step = 72/100
# Step = 73/100
# Step = 74/100
# Step = 75/100
# Step = 76/100
# Step = 77/100
# Step = 78/100
# Step = 79/100
# Step = 80/100
# Step = 81/100
# Step = 82/100
# Step = 83/100
# Step = 84/100
# Step = 85/100
# Step = 86/100
# Step = 87/100
# Step = 88/100
# Step = 89/100
# Step = 90/100
# Step = 91/100
# Step = 92/100
# Step = 93/100
# Step = 94/100
# Step = 95/100
# Step = 96/100
# Step = 97/100
# Step = 98/100
# Step = 99/100
# Step = 100/100
# -------------------------------------------------------------------------------
#
# Generating chebfun2 models:
# Training greenlearning model for example 'interior_layer' at Theta = 0.07
# Training with Adam:
# Loss at epoch 100: Training = 4.453E-01, Validation = 4.870E-01
# Loss at epoch 4500: Training = 2.431E-04, Validation = 5.364E-04
# Loss at epoch 4600: Training = 6.220E-04, Validation = 1.174E-03
# Loss at epoch 4700: Training = 2.297E-04, Validation = 4.994E-04
# Loss at epoch 4800: Training = 2.218E-04, Validation = 4.756E-04
# Loss at epoch 4900: Training = 2.435E-04, Validation = 4.727E-04
# Loss at epoch 5000: Training = 2.100E-04, Validation = 4.435E-04
# Training with LBFGS:
# Learning a chebfun model for example 'interior_layer' at Theta = 0.07
# Chebfun model added for example 'interior_layer' at Theta = 0.07

# %%
fig = plt.figure()
Ginterp.plot(fig = fig)
error = schrodinger.computeEmpiricalError(theta_)
plt.title(f"Interpolated Model $\\theta = {{{theta_:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# Out:
# Text(0.5, 1.0, 'Interpolated Model $\\theta = {0.07}$,$\\epsilon_{test} = {1.83}\\%$')

# %%
fig = plt.figure()
validation.G[theta_].plot(fig = fig)
error = validation.computeEmpiricalError(theta_)
plt.title(f"Validation Model $\\theta = {{{theta_:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# Out:
# Text(0.5, 1.0, 'Validation Model $\\theta = {0.07}$,$\\epsilon_{test} = {1.34}\\%$')

# %%
def compareGreen1D(interpModel, exactModel, vmin = None, vmax = None):
    domain = interpModel.domain
    xx = np.linspace(domain[2],domain[3],2000)
    yy = np.linspace(domain[0],domain[1],2000)
    x, s = np.meshgrid(xx,yy)
    
    if vmin is None:
        vmin = min(interpModel.min,exactModel.min)
    if vmax is None:
        vmax = max(interpModel.max,exactModel.max)
        
    plt.figure(figsize = (16,6))
    plt.subplot(121)
    
    GInterp = interpModel[x,s]
    
    levels = np.linspace(vmin, vmax, 50, endpoint = True)
    ticks = np.linspace(vmin, vmax, 10, endpoint=True)
    
    surf = plt.contourf(x, s, GInterp, levels = levels, cmap = 'turbo', vmin = vmin, vmax = vmax)
    plt.gca().set_aspect('equal', adjustable='box')
    cbar = plt.colorbar(ticks = ticks, fraction = 0.046, pad = 0.04)
    cbar.ax.set_yticklabels(["{:4.2f}".format(i) for i in ticks])
    plt.xlabel('$x$', fontsize = 11)
    plt.ylabel('$s$', rotation='horizontal', labelpad=10, fontsize = 11)
    plt.title("Interpolated", fontsize = 14)
    
    GExact = exactModel[x,s]
    
    plt.subplot(122)
    plt.gca().set_aspect('equal', adjustable='box')
    surf = plt.contourf(x, s, GExact, levels = levels, cmap = 'turbo', vmin = vmin, vmax = vmax)
    cbar = plt.colorbar(ticks = ticks, fraction = 0.046, pad = 0.04)
    cbar.ax.set_yticklabels(["{:4.2f}".format(i) for i in ticks])
    plt.xlabel('x', fontsize = 11)
    plt.ylabel('s', rotation='horizontal', labelpad=10, fontsize = 11)
    plt.title("Data", fontsize = 14)

# %%
compareGreen1D(Ginterp,validation.G[theta_])
