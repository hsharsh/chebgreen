# %%
from chebgreen import ChebGreen
import numpy as np
import matplotlib.pyplot as plt

from chebgreen.chebpy2 import Quasimatrix
from chebgreen.chebpy2.chebpy import chebfun
from chebgreen.chebpy2 import Chebfun2

# %%
Theta = [6.0,7.0,8.0]
# Theta = [5.0]
theta_ = 9.0
domain = [0,1,0,1]
generateData = True
script = "generate_example"
example = "airy_equation"
dirichletBC = True

# %%
# %%time
model = ChebGreen(Theta, domain, generateData, script, example, dirichletBC)
# Out:
# Generating dataset for example 'airy_equation'
# Dataset found for Theta = 6.00. Skipping dataset generation.
# Dataset found for Theta = 7.00. Skipping dataset generation.
# Dataset found for Theta = 8.00. Skipping dataset generation.
# -------------------------------------------------------------------------------
#
# Generating chebfun2 models:
# Found saved model, Loading model for example 'airy_equation' at Theta = 6.00
# Learning a chebfun model for example 'airy_equation' at Theta = 6.00
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/model.py:74, in ChebGreen.__init__(self, Theta, domain, generateData, script, example, dirichletBC, datapath)
#      72 print("-------------------------------------------------------------------------------\n")
#      73 print("Generating chebfun2 models:")
# ---> 74 self.generateChebfun2Models(example)
#      75 self.interpG = {}
#      76 self.interpN = {}
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/model.py:120, in ChebGreen.generateChebfun2Models(self, example)
#     118 if parser.has_option('CHEBFUN', 'eps_y'):
#     119     prefs.prefy.eps = parser['CHEBFUN'].getfloat('eps_y')
# --> 120 self.G[float(theta)] = (Chebfun2(model.evaluateG, domain = self.domain, prefs = prefs, simplify = True))
#     121 print(f"Chebfun model added for example \'{example}\' at Theta = {theta:.2f}\n")
#     123 # Store the homogeneous solution
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/chebpy2/chebfun2.py:52, in Chebfun2.__init__(self, g, domain, prefs, simplify, vectorize)
#      50     self.domain = np.hstack([self.rows.domain,self.cols.domain])
#      51 else:
# ---> 52     self.cols, self.rows, self.pivotValues, self.pivotLocations = self.constructor(lambda x,y: g(x,y), vectorize)
#      54 # Simplify the Chebfun2 object using a singular value decomposition. We truncate to the rank floor(2*n/pi) where n is the number of pivot values.
#      55 if simplify:
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/chebpy2/chebfun2.py:146, in Chebfun2.constructor(self, g, vectorize)
#     144 grid[1], _ = gridRefine(grid[1], prefy)
#     145 xx, yy = points2D(grid[0],grid[1],self.domain,prefx,prefy)
# --> 146 vals = evaluate(g, xx, yy) # Resample
#     147 vscale = np.max(np.abs(vals[:]))
#     149 #New Tolerance
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/chebpy2/chebfun2.py:523, in evaluate(op, xx, yy, vectorize)
#     521             vals[jj, kk] = op( xx(0,kk), yy(jj,0))
#     522 else:
# --> 523     vals = op(xx,yy)  # Matrix of values at cheb2 pts.
#     524 return vals
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/chebpy2/chebfun2.py:52, in Chebfun2.__init__.<locals>.<lambda>(x, y)
#      50     self.domain = np.hstack([self.rows.domain,self.cols.domain])
#      51 else:
# ---> 52     self.cols, self.rows, self.pivotValues, self.pivotLocations = self.constructor(lambda x,y: g(x,y), vectorize)
#      54 # Simplify the Chebfun2 object using a singular value decomposition. We truncate to the rank floor(2*n/pi) where n is the number of pivot values.
#      55 if simplify:
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/greenlearning/model.py:271, in GreenNN.evaluateG(self, x, s)
#     266 with torch.no_grad():
#     267     # Evaluate the Green's function depending on whether the approximate distance function was added to the loss
#     268     if self.addADF:
#     269         G = (approximateDistanceFunction(X[:,0], X[:,1],
#     270                                      self.domain.astype(config(np)),
# --> 271                                      self.device).reshape((-1,1))*self.G(X)).cpu().numpy().reshape(shape)
#     272     else:
#     273         G = self.G(X).cpu().numpy().reshape(shape)
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/greenlearning/model.py:69, in NN.forward(self, X)
#      65 def forward(self, X: torch.Tensor) -> torch.Tensor:
#      66
#      67     # Loop over all the layers and activation functions.
#      68     for layer, activation in zip(self.layers[:-1],self.activationFunctions):
# ---> 69         X = activation(layer(X))
#      71     # Last layer does not take an activation function.
#      72     return self.layers[-1](X)
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/harsh/chebgreen/.venv/lib/python3.12/site-packages/chebgreen/greenlearning/activations.py:30, in Rational.forward(self, inputs)
#      27 def forward(self,
#      28         inputs: torch.Tensor
#      29         ) -> torch.Tensor:
# ---> 30     Num = self.Pcoeffs[3] + inputs*(self.Pcoeffs[2] + inputs*(self.Pcoeffs[1] + inputs*self.Pcoeffs[0]))
#      31     Den = self.Qcoeffs[2] + inputs*(self.Qcoeffs[1] + inputs*self.Qcoeffs[0])
#      32     return torch.div(Num,Den)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.56 GiB. GPU 0 has a total capacity of 15.73 GiB of which 1.51 GiB is free. Process 2041681 has 10.66 GiB memory in use. Including non-PyTorch memory, this process has 3.54 GiB memory in use. Of the allocated memory 3.23 GiB is allocated by PyTorch, and 121.65 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
model.G
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.G
#
# NameError: name 'model' is not defined

# %%
model.N
# Out:
# {1.0: chebfun (1 smooth piece)
#         interval       length     endpoint values
#  [       0,       1]       18  -9.3e-05  5.3e-05
#  vertical scale = 9.3e-05,
#  5.0: chebfun (1 smooth piece)
#         interval       length     endpoint values
#  [       0,       1]       28   1.5e-05  0.00014
#  vertical scale = 0.00014,
#  10.0: chebfun (1 smooth piece)
#         interval       length     endpoint values
#  [       0,       1]       25   0.00017 -1.7e-05
#  vertical scale = 0.00017}

# %%
# %%time
for t in Theta:
    fig = plt.figure()
    model.G[t].plot(fig = fig)
    error = model.computeEmpiricalError(t)
    plt.title(f"$\\theta = {{{t:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# Out:
# CPU times: user 2min 13s, sys: 148 ms, total: 2min 13s
# Wall time: 36.7 s

# %%
# %%time
u,s,v = model.G[Theta[0]].svd()
# Out:
# CPU times: user 28 s, sys: 8.59 ms, total: 28 s
# Wall time: 7.71 s

# %%
fig = plt.figure(figsize = (8,6))
plt.plot(s)
plt.yscale('log')
plt.grid(True)

# %%
# i = slice(10,20)
i = slice(0,5)
# i = 16
fig = plt.figure(figsize = (8,6))
u[:,i].plot(fig = fig)
# print(np.max(u[:,i].vscale))
# plt.title(f'First {i+1} left singular functions for a Laplacian')
plt.xlim([0,1])
# fig.savefig(f'Laplace-first.png', dpi = fig.dpi)
# Out:
# (0.0, 1.0)

# %%
# %%time
Ginterp, Ninterp = model.generateNewModel(theta_)
# Out:
# CPU times: user 3min 43s, sys: 49.7 ms, total: 3min 43s
# Wall time: 1min 29s

# %%
validation = ChebGreen([theta_], domain, generateData, script, example, dirichletBC)
# Out:
# Generating dataset for example 'airy_equation'
# ### Example = airy_equation @ theta = 11 ###
# Number of samples: 100
# Length scale: 0.01
# Nf: 500
# Nu: 500
# Noise: 0%
# ---------------------------------------
# Step = 1/100
# Step = 2/100
# Step = 3/100
# Step = 4/100
# Step = 5/100
# Step = 6/100
# Step = 7/100
# Step = 8/100
# Step = 9/100
# Step = 10/100
# Step = 11/100
# Step = 12/100
# Step = 13/100
# Step = 14/100
# Step = 15/100
# Step = 16/100
# Step = 17/100
# Step = 18/100
# Step = 19/100
# Step = 20/100
# Step = 21/100
# Step = 22/100
# Step = 23/100
# Step = 24/100
# Step = 25/100
# Step = 26/100
# Step = 27/100
# Step = 28/100
# Step = 29/100
# Step = 30/100
# Step = 31/100
# Step = 32/100
# Step = 33/100
# Step = 34/100
# Step = 35/100
# Step = 36/100
# Step = 37/100
# Step = 38/100
# Step = 39/100
# Step = 40/100
# Step = 41/100
# Step = 42/100
# Step = 43/100
# Step = 44/100
# Step = 45/100
# Step = 46/100
# Step = 47/100
# Step = 48/100
# Step = 49/100
# Step = 50/100
# Step = 51/100
# Step = 52/100
# Step = 53/100
# Step = 54/100
# Step = 55/100
# Step = 56/100
# Step = 57/100
# Step = 58/100
# Step = 59/100
# Step = 60/100
# Step = 61/100
# Step = 62/100
# Step = 63/100
# Step = 64/100
# Step = 65/100
# Step = 66/100
# Step = 67/100
# Step = 68/100
# Step = 69/100
# Step = 70/100
# Step = 71/100
# Step = 72/100
# Step = 73/100
# Step = 74/100
# Step = 75/100
# Step = 76/100
# Step = 77/100
# Step = 78/100
# Step = 79/100
# Step = 80/100
# Step = 81/100
# Step = 82/100
# Step = 83/100
# Step = 84/100
# Step = 85/100
# Step = 86/100
# Step = 87/100
# Step = 88/100
# Step = 89/100
# Step = 90/100
# Step = 91/100
# Step = 92/100
# Step = 93/100
# Step = 94/100
# Step = 95/100
# Step = 96/100
# Step = 97/100
# Step = 98/100
# Step = 99/100
# Step = 100/100
# Forcing functions represented by 433 chebyshev points.
# -------------------------------------------------------------------------------
#
# Generating chebfun2 models:
# Training greenlearning model for example 'airy_equation' at Theta = 11.00
# Training with Adam:
# Loss at epoch 100: Training = 5.107E-03, Validation = 5.380E-03
# Loss at epoch 200: Training = 1.645E-03, Validation = 2.503E-03
# Loss at epoch 300: Training = 9.804E-04, Validation = 1.489E-03
# Loss at epoch 400: Training = 6.704E-04, Validation = 1.044E-03
# Loss at epoch 500: Training = 6.459E-04, Validation = 1.619E-03
# Loss at epoch 600: Training = 3.583E-04, Validation = 4.367E-04
# Loss at epoch 700: Training = 2.940E-04, Validation = 3.368E-04
# Loss at epoch 800: Training = 2.560E-04, Validation = 2.925E-04
# Loss at epoch 900: Training = 2.380E-04, Validation = 2.773E-04
# Loss at epoch 1000: Training = 2.163E-04, Validation = 2.498E-04
# Loss at epoch 1100: Training = 1.995E-04, Validation = 2.320E-04
# Loss at epoch 1200: Training = 1.859E-04, Validation = 2.173E-04
# Loss at epoch 1300: Training = 1.746E-04, Validation = 2.047E-04
# Loss at epoch 1400: Training = 1.649E-04, Validation = 1.938E-04
# Loss at epoch 1500: Training = 1.566E-04, Validation = 1.841E-04
# Loss at epoch 1600: Training = 1.494E-04, Validation = 1.754E-04
# Loss at epoch 1700: Training = 1.431E-04, Validation = 1.677E-04
# Loss at epoch 1800: Training = 1.374E-04, Validation = 1.607E-04
# Loss at epoch 1900: Training = 1.324E-04, Validation = 1.545E-04
# Loss at epoch 2000: Training = 1.279E-04, Validation = 1.488E-04
# Training with LBFGS:
# Learning a chebfun model for example 'airy_equation' at Theta = 11.00
# Chebfun model added for example 'airy_equation' at Theta = 11.00

# %%
# vmin, vmax = -0.24,0.03
# Gplot = validation.G[theta_]

# xx = np.linspace(domain[0],domain[1],2000)
# yy = np.linspace(domain[2],domain[3],2000)
# x, y = np.meshgrid(xx,yy)
# Gplot = Gplot[x,y]

# fig = plt.figure(figsize = (13,10), frameon=False)
# plt.axis('off')
# plt.gca().set_aspect('equal', adjustable='box')
# levels = np.linspace(vmin, vmax, 50, endpoint = True)
# plt.contourf(x,y,Gplot, levels = levels, cmap = 'jet', vmin = vmin, vmax = vmax)
# # ticks = np.linspace(vmin, vmax, 6, endpoint=True)
# # cbar = plt.colorbar(ticks = ticks, fraction = 0.046, pad = 0.04)

# fig.savefig('E.png', dpi = fig.dpi, bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure()
Ginterp.plot(fig = fig)
error = model.computeEmpiricalError(theta_)
plt.title(f"Interpolated Model $\\theta = {{{theta_:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# fig.savefig(f'poisson_greenlearning.png', dpi = fig.dpi)
# Out:
# Text(0.5, 1.0, 'Interpolated Model $\\theta = {11.00}$,$\\epsilon_{test} = {9.32}\\%$')

# %%
fig = plt.figure()
validation.G[theta_].plot(fig = fig)
error = validation.computeEmpiricalError(theta_)
plt.title(f"Validation Model $\\theta = {{{theta_:4.2f}}}$,$\\epsilon_{{test}} = {{{error*100:4.2f}}}\\%$")
# Out:
# Text(0.5, 1.0, 'Validation Model $\\theta = {11.00}$,$\\epsilon_{test} = {1.01}\\%$')

# %%
def compareGreen1D(interpModel, exactModel, vmin = None, vmax = None):
    domain = interpModel.domain
    xx = np.linspace(domain[2],domain[3],2000)
    yy = np.linspace(domain[0],domain[1],2000)
    x, s = np.meshgrid(xx,yy)
    
    if vmin is None:
        vmin = min(interpModel.min,exactModel.min)
    if vmax is None:
        vmax = max(interpModel.max,exactModel.max)
        
    plt.figure(figsize = (16,6))
    plt.subplot(121)
    
    GInterp = interpModel[x,s]
    
    levels = np.linspace(vmin, vmax, 50, endpoint = True)
    ticks = np.linspace(vmin, vmax, 10, endpoint=True)
    
    surf = plt.contourf(x, s, GInterp, levels = levels, cmap = 'turbo', vmin = vmin, vmax = vmax)
    plt.gca().set_aspect('equal', adjustable='box')
    cbar = plt.colorbar(ticks = ticks, fraction = 0.046, pad = 0.04)
    cbar.ax.set_yticklabels(["{:4.2f}".format(i) for i in ticks])
    plt.xlabel('$x$', fontsize = 11)
    plt.ylabel('$s$', rotation='horizontal', labelpad=10, fontsize = 11)
    plt.title("Interpolated", fontsize = 14)
    
    GExact = exactModel[x,s]
    
    plt.subplot(122)
    plt.gca().set_aspect('equal', adjustable='box')
    surf = plt.contourf(x, s, GExact, levels = levels, cmap = 'turbo', vmin = vmin, vmax = vmax)
    cbar = plt.colorbar(ticks = ticks, fraction = 0.046, pad = 0.04)
    cbar.ax.set_yticklabels(["{:4.2f}".format(i) for i in ticks])
    plt.xlabel('x', fontsize = 11)
    plt.ylabel('s', rotation='horizontal', labelpad=10, fontsize = 11)
    plt.title("Data", fontsize = 14)

# %%
compareGreen1D(Ginterp,validation.G[theta_])
